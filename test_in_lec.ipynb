# %%
name = "amr"
print(type(name))
list_1=list(name)
type(list_1)
# Out:
# <class 'str'>
# list

# %%
num = 5,6
list(num)
print(type(num))
# Out:
# <class 'tuple'>

# %%
list = [1, 2, 3]
list.append(4)
print(list)
# Out:
# [1, 2, 3, 4]

# %%
from matplotlib.pylab import insert


list_2 = [1,2,3,4]
list_2.insert(2,'amit')
print(list_2)
# Out:
# [1, 2, 'amit', 3, 4]

# %%
list_3=['a','b','c','d']
list_2.extend(['e','f'])
print(list_2)
# Out:
# [1, 2, 'amit', 3, 4, 'e', 'f', 'e', 'f', 'e', 'f']

# %%
list_3=['a','b','c','d']
list_2.extend(['e','f'])
print(list_2)
# Out:
# [1, 2, 'amit', 3, 4, 'e', 'f']

# %%
list_2 = [1,2,3,4]
list_2.remove(2)
print(list_2)
# Out:
# [1, 3, 4]

# %%
list_2 = [1,2,3,4]
list_2.remove(2)
print(list_2)
# Out:
# [1, 3, 4]

# %%
list_2 = [1,2,3,4]
list_2.pop(1)
print(list_2)
# Out:
# [1, 3, 4]

# %%
my_list = [10, 20, 30, 40, 50]
my_list.index(20)
# Out:
# 1

# %%
my_list = [10, 20, 20, 40, 50]
my_list.count(20)
# Out:
# 2

# %%
my_list2 = [5, 15, 25, 35, 45]
my_list2.reverse()
print(my_list2)
my_list2.clear()
print(my_list2)
# Out:
# [45, 35, 25, 15, 5]
# []

# %%
name = "amr"
tuple(name)
# Out:
# ('a', 'm', 'r')

# %%
my_tuple = ('a', 'b', 'c')
tuple(my_tuple)
print(my_tuple)
# Out:
# ('a', 'b', 'c')

# %%
a=200 
b=100
if b>a:
    print("b is greater than a")
else:
    print("a is greater than b")
# Out:
# a is greater than b
