# %%
#import math
import random
n=random.random()
n
# Out:
# 0.5091127343354679

# %%
import os
import sys

# %%
base="c:/Users/user/OneDrive/Desktop/depi/DEPI_GIZA_AIS4_S1_DS/src/python/SESSION 4"
import os
import sys

# %%
# Safely list the contents of `base`. If `base` does not exist, print a message
# and fall back to listing the current working directory.
base_path = os.path.normpath(base)  # normalize path for the OS
if os.path.exists(base_path):
	files = os.listdir(base_path)
	print(f"Listing contents of: {base_path}")
	print(files)
else:
	print(f"Base path does not exist: {base_path}")
	# fallback: list current working directory
	files = os.listdir(".")
	print("Listing current working directory instead:")
	print(files)
# Out:
# Base path does not exist: c:\Users\user\OneDrive\Desktop\depi\DEPI_GIZA_AIS4_S1_DS\src\python\SESSION 4
# Listing current working directory instead:
# ['code_4.ipynb', 'tmp_directory']

# %%
# create base directory (os already imported in another cell)
path = "tmp_directory"
os.makedirs(path, exist_ok=True)
for i in range(20):
    inner_path = os.path.join(path, "dir_" + str(i))
    os.makedirs(inner_path, exist_ok=True)

# %%
"""_summary_
"""
class studentinfo :
    student_name = "amr "
    age = 20
    gpa = 3.99
    gender="male"
    def student_details(self,name):
        return f"student name is"

# %%
s1 = studentinfo()
print(s1.student_name, s1.age, s1.gpa, s1.gender)
# Out:
# amr  20 3.99 male

# %%
s1.student_name
# Out:
# 'AMR'

# %%
s1.age=21
s1.age
# Out:
# 21

# %%
t1 = test ()
def info (self):
    print (self)
# Out:
# this is constructor

# %%
class test :
    def __init__(self):
        print("this is constructor")
