# %%
import os
import random

# %%
def thanos_project(folder_path, num_files=10):
    if not os.path.exists(folder_path):
        os.makedirs(folder_path)
        print(f"Folder created: {folder_path}")
    else:
        print(f"Folder exists: {folder_path}")

# %%
def thanos_project(folder_path, num_files=10):
    if not os.path.exists(folder_path):
        os.makedirs(folder_path)
        print(f"Folder created: {folder_path}")
    else:
        print(f"Folder exists: {folder_path}")

    for i in range(num_files):
        file_path = os.path.join(folder_path, f"file_{i}.txt")
        with open(file_path, 'w') as f:
            f.write(f"This is file {i}")
    print(f"{num_files} files created.")

    files = os.listdir(folder_path)
    print(f"Total files before deletion: {len(files)}")

    half_count = len(files) // 2
    files_to_delete = random.sample(files, half_count)
    for file in files_to_delete:
        os.remove(os.path.join(folder_path, file))
    print(f"Deleted {half_count} files randomly.")

    remaining_files = os.listdir(folder_path)
    print(f"Files remaining after deletion: {len(remaining_files)}")
    print("Remaining files:", remaining_files)

# %%
# Safely list the contents of `base`. If `base` does not exist, print a message
# and fall back to listing the current working directory.
base_path = os.path.normpath(base)  # normalize path for the OS
if os.path.exists(base_path):
	files = os.listdir(base_path)
	print(f"Listing contents of: {base_path}")
	print(files)
else:
	print(f"Base path does not exist: {base_path}")
	# fallback: list current working directory
	files = os.listdir(".")
	print("Listing current working directory instead:")
	print(files)
# Out:
# Base path does not exist: c:\Users\user\OneDrive\Desktop\depi\DEPI_GIZA_AIS4_S1_DS\src\python\SESSION 4
# Listing current working directory instead:
# ['code_4.ipynb', 'task4.ipynb', 'task@4.ipynb', 'thanos_folder', 'tmp_directory']

# %%
thanos_project("than    os_folder", num_files=10)
# Out:
# Folder created: than    os_folder
# 10 files created.
# Total files before deletion: 10
# Deleted 5 files randomly.
# Files remaining after deletion: 5
# Remaining files: ['file_0.txt', 'file_1.txt', 'file_6.txt', 'file_7.txt', 'file_8.txt']
