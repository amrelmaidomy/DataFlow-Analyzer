# %%
print("hello")
# Out:
# hello

# %%
print("my age is 20",25)
# Out:
# my age is 20 25

# %%
age=30

# %%
print("my age is",age)
# Out:
# my age is 30

# %%
x = "amr"
type(x)
#type data
# Out:
# str

# %%
# --- IGNORE --- control ظ 
'''
Docstring for python.session_1.code.basic.ipynb
'''
# Out:
# '\nDocstring for python.session_1.code.basic.ipynb\n'

# %%
name="amr"
age=20
"my name is {0}, my age is {1}".format(name, age)
# Out:
# 'my name is amr, my age is 20'

# %%
f"my name is {name}, my age is {age}"
# Out:
# 'my name is amr, my age is 20'

# %%
def get():
    return f"my name is {name}, my age is {age}"

# %%
name = "depi_ds"
name[-4]
# Out:
# 'i'

# %%
name = "amit learning"
print(name[0:4:1])
namename = name.upper()
print(name, namename)
# Out:
# amit
# amit learning AMIT LEARNING

# %%
my_string = "0123456789"
print(my_string[-2:-6:-2])
# Out:
# 86
